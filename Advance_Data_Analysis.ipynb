# %%
pwd
# Out:
# 'C:\\Users\\ANJARAJE\\Desktop\\python_practice\\Python_cap'

# %%
import pandas as pd

# %%
fortune_5=pd.read_csv("f500.csv")

# %%
fortune_5
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
#which comapny is ,making the highest profit
fortune_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
fortune_5['profits']
# Out:
# 0      13643.0
# 1       9571.3
# 2       1257.9
# 3       1867.5
# 4      16899.3
#         ...
# 495      329.0
# 496      743.9
# 497      406.4
# 498     1151.7
# 499      430.5
# Name: profits, Length: 500, dtype: float64

# %%
fortune_5['profits'].max()  #highest profit is 45687.0 millions dollar
# Out:
# 45687.0

# %%
# boolean values Example.....to fetch out True results.......

# %%
fortune_5['profits']>45000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: profits, Length: 500, dtype: bool

# %%
fortune_5['profits']==45687
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: profits, Length: 500, dtype: bool

# %%
# boolean indexing.......... only true value will fetch
fortune_5[fortune_5['profits']==45687]   #on numerical data
# Out:
#   company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 8   Apple     9    215639            -7.7  45687.0  321686          -14.4
#
#                ceo                     industry      sector  previous_rank  \
# 8  Timothy D. Cook  Computers, Office Equipment  Technology              9
#
#   country    hq_location               website  years_on_global_500_list  \
# 8     USA  Cupertino, CA  http://www.apple.com                        15
#
#    employees  total_stockholder_equity
# 8     116000                    128249

# %%
fortune_5[fortune_5['profits']!=45687].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   499 non-null    object
#  1   rank                      499 non-null    int64
#  2   revenues                  499 non-null    int64
#  3   revenue_change            497 non-null    float64
#  4   profits                   498 non-null    float64
#  5   assets                    499 non-null    int64
#  6   profit_change             435 non-null    float64
#  7   ceo                       499 non-null    object
#  8   industry                  499 non-null    object
#  9   sector                    499 non-null    object
#  10  previous_rank             499 non-null    int64
#  11  country                   499 non-null    object
#  12  hq_location               499 non-null    object
# ...

# %%
# groups .....to find .....unique sector
#some of the modules in pandas are utilizing numpy

fortune_5['sector'].unique() # iterating .....over the numpy module
# Out:
# array(['Retailing', 'Energy', 'Motor Vehicles & Parts', 'Financials',
#        'Technology', 'Wholesalers', 'Health Care', 'Telecommunications',
#        'Engineering & Construction', 'Industrials', 'Food & Drug Stores',
#        'Aerospace & Defense', 'Food, Beverages & Tobacco',
#        'Household Products', 'Transportation', 'Materials', 'Chemicals',
#        'Media', 'Apparel', 'Hotels, Restaurants & Leisure',
#        'Business Services'], dtype=object)

# %%
fortune_5['industry']
# Out:
# 0                General Merchandisers
# 1                            Utilities
# 2                   Petroleum Refining
# 3                   Petroleum Refining
# 4             Motor Vehicles and Parts
#                     ...
# 495                    Pharmaceuticals
# 496    Insurance: Life, Health (stock)
# 497               Food and Drug Stores
# 498                    Travel Services
# 499                Specialty Retailers
# Name: industry, Length: 500, dtype: object

# %%
fortune_5['industry'].unique() #name of industries unique
# Out:
# array(['General Merchandisers', 'Utilities', 'Petroleum Refining',
#        'Motor Vehicles and Parts',
#        'Insurance: Property and Casualty (Stock)',
#        'Computers, Office Equipment', 'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care',
#        'Health Care: Pharmacy and Other Services',
#        'Electronics, Electrical Equip.', 'Mining, Crude-Oil Production',
#        'Telecommunications', 'Diversified Financials',
#        'Banks: Commercial and Savings', 'Engineering, Construction',
#        'Insurance: Life, Health (stock)',
#        'Internet Services and Retailing', 'Industrial Machinery',
#        'Food and Drug Stores', 'Trading', 'Specialty Retailers',
#        'Aerospace and Defense', 'Energy', 'Food Consumer Products',
#        'Computer Software', 'Information Technology Services',
#        'Network and Other Communications Equipment',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
# ...

# %%
len(fortune_5['industry'].unique())
# Out:
# 58

# %%
# boolean indexing......
fortune_5['sector']=='Energy'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: sector, Length: 500, dtype: bool

# %%
# boolean indexing......only load true
fortune_5[fortune_5['sector']=='Energy']
# Out:
#                                           company  rank  revenues  \
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 6                               Royal Dutch Shell     7    240033
# 9                                     Exxon Mobil    10    205004
# ..                                            ...   ...       ...
# 468                  Enterprise Products Partners   469     23022
# 475  Shanxi Jincheng Anthracite Coal Mining Group   476     22875
# 485                                     GS Caltex   486     22207
# 486                             Ultrapar Holdings   487     22167
# 490                                 National Grid   491     22036
#
#      revenue_change  profits  assets  profit_change              ceo  \
# 1              -4.4   9571.3  489838           -6.2          Kou Wei
# ...

# %%
fortune_5[fortune_5['sector']=='Wholesalers']
# Out:
#                                    company  rank  revenues  revenue_change  \
# 10                                McKesson    11    198533             3.1
# 22                       AmerisourceBergen    23    146850             8.0
# 34                         Cardinal Health    35    121546            18.5
# 53                         Trafigura Group    54     98098             0.9
# 115                               Marubeni   116     65792             8.2
# 128                            Tewoo Group   129     63324            -1.4
# 135                                  COFCO   136     61265            -5.0
# 142                         Sinochem Group   143     59533            -1.9
# 144                             Mitsubishi   145     59303             2.8
# 178                                  Sysco   179     50367             3.5
# 204                            Noble Group   205     46528           -30.3
# ...

# %%
len(fortune_5['industry']=='Banks: Commercial and Savings' )
# Out:
# 500

# %%
fortune_5[fortune_5['industry']=='Banks: Commercial and Savings']
# Out:
#                                    company  rank  revenues  revenue_change  \
# 21   Industrial & Commercial Bank of China    22    147675           -11.7
# 27                 China Construction Bank    28    135093            -8.7
# 37              Agricultural Bank of China    38    117275           -12.1
# 41                           Bank of China    42    113708            -7.1
# 42                             BNP Paribas    43    109026            -2.2
# 47                       J.P. Morgan Chase    48    105486             4.4
# 60                             Wells Fargo    61     94176             4.6
# 61                   Bank of America Corp.    62     93662             0.7
# 72                         Banco Santander    73     82801            -2.5
# 73                               Citigroup    74     82386            -6.7
# 79                         Credit Agricole    80     80258            -4.6
# ...

# %%
fortune_5[fortune_5['sector'] == 'Wholesalers'][fortune_5[fortune_5['sector'] == 'Wholesalers']['industry'] == 'Trading']
# Out:
#                                    company  rank  revenues  revenue_change  \
# 53                         Trafigura Group    54     98098             0.9
# 115                               Marubeni   116     65792             8.2
# 128                            Tewoo Group   129     63324            -1.4
# 135                                  COFCO   136     61265            -5.0
# 142                         Sinochem Group   143     59533            -1.9
# 144                             Mitsubishi   145     59303             2.8
# 204                            Noble Group   205     46528           -30.3
# 214                                 Itochu   215     44654             5.5
# 248                                 Mitsui   249     40275             1.6
# 281                               Sumitomo   282     36888            10.4
# 294                         Rajesh Exports   295     36114            43.1
# ...

# %%
# filtering...
# on the basis of rows... # string rows...
# on the basis of int
# on the basis of conditionals
# on the basis of index values
# # on the basis of combination of columns and rows.

# %%
fortune_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
15.00==15
# Out:
# True

# %%
# descriptive statistics
#for one column

fortune_5['profits'].describe()
# Out:
# count      499.000000
# mean      3055.203206
# std       5171.981071
# min     -13038.000000
# 25%        556.950000
# 50%       1761.600000
# 75%       3954.000000
# max      45687.000000
# Name: profits, dtype: float64

# %%
#sort descending order
#top 10 profit earned
# name of those companies

# %%
fortune_5['profits'].sort_values(ascending=False) #sort in descending order
# Out:
# 8      45687.0
# 21     41883.9
# 27     34840.9
# 37     27687.8
# 41     24773.4
#         ...
# 148    -6904.0
# 230    -9344.4
# 151   -10256.3
# 327   -13038.0
# 456        NaN
# Name: profits, Length: 500, dtype: float64

# %%
fortune_5['profits'].sort_values(ascending=False)[0:10]
# Out:
# 8     45687.0
# 21    41883.9
# 27    34840.9
# 37    27687.8
# 41    24773.4
# 47    24733.0
# 7     24074.0
# 60    21938.0
# 64    19478.0
# 14    19316.5
# Name: profits, dtype: float64

# %%
# 19316.5 at the 10th highest profit in the fortune 500 list companies

 

# boolean indexing....
fortune_5[fortune_5['profits'] >= 19316.5].sort_values('profits', ascending = False)
# Out:
#                                   company  rank  revenues  revenue_change  \
# 8                                   Apple     9    215639            -7.7
# 21  Industrial & Commercial Bank of China    22    147675           -11.7
# 27                China Construction Bank    28    135093            -8.7
# 37             Agricultural Bank of China    38    117275           -12.1
# 41                          Bank of China    42    113708            -7.1
# 47                      J.P. Morgan Chase    48    105486             4.4
# 7                      Berkshire Hathaway     8    223604             6.1
# 60                            Wells Fargo    61     94176             4.6
# 64                               Alphabet    65     90272            20.4
# 14                    Samsung Electronics    15    173957            -2.0
#
#     profits   assets  profit_change                ceo  \
# 8   45687.0   321686          -14.4    Timothy D. Cook
# ...

# %%
#find out all the companies which are earning more
#than average profit in dataset .......and sort them in descending order

fortune_5[fortune_5['profits'] > fortune_5['profits'].mean()].sort_values('profits',ascending=False)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 8                                    Apple     9    215639            -7.7
# 21   Industrial & Commercial Bank of China    22    147675           -11.7
# 27                 China Construction Bank    28    135093            -8.7
# 37              Agricultural Bank of China    38    117275           -12.1
# 41                           Bank of China    42    113708            -7.1
# ..                                     ...   ...       ...             ...
# 81                   Electricite de France    82     78740            -5.4
# 288                              Pertamina   289     36487           -12.6
# 212                            Continental   213     44842             3.0
# 121                                 Lowe’s   122     65017            10.1
# 101                                 Lukoil   102     70897           -16.3
#
#      profits   assets  profit_change                 ceo  \
# ...

# %%
#fetch multiple columns and queries
#conventional way .............list pattern
#.loc..........Location
#.iloc ........index Location

# %%
fortune_5[['company','rank','revenues','profits','ceo']][0:10] #fetching 1st 10 rows
# Out:
#                     company  rank  revenues  profits                  ceo
# 0                   Walmart     1    485873  13643.0  C. Douglas McMillon
# 1                State Grid     2    315199   9571.3              Kou Wei
# 2             Sinopec Group     3    267518   1257.9            Wang Yupu
# 3  China National Petroleum     4    262573   1867.5        Zhang Jianhua
# 4              Toyota Motor     5    254694  16899.3          Akio Toyoda
# 5                Volkswagen     6    240264   5937.3      Matthias Muller
# 6         Royal Dutch Shell     7    240033   4575.0      Ben van Beurden
# 7        Berkshire Hathaway     8    223604  24074.0    Warren E. Buffett
# 8                     Apple     9    215639  45687.0      Timothy D. Cook
# 9               Exxon Mobil    10    205004   7840.0      Darren W. Woods

# %%
fortune_5[0:10][['company','rank','revenues','profits','ceo']]
# Out:
#                     company  rank  revenues  profits                  ceo
# 0                   Walmart     1    485873  13643.0  C. Douglas McMillon
# 1                State Grid     2    315199   9571.3              Kou Wei
# 2             Sinopec Group     3    267518   1257.9            Wang Yupu
# 3  China National Petroleum     4    262573   1867.5        Zhang Jianhua
# 4              Toyota Motor     5    254694  16899.3          Akio Toyoda
# 5                Volkswagen     6    240264   5937.3      Matthias Muller
# 6         Royal Dutch Shell     7    240033   4575.0      Ben van Beurden
# 7        Berkshire Hathaway     8    223604  24074.0    Warren E. Buffett
# 8                     Apple     9    215639  45687.0      Timothy D. Cook
# 9               Exxon Mobil    10    205004   7840.0      Darren W. Woods

# %%
fortune_5[['company', 'rank','revenues','profits','ceo']][fortune_5['profits']>= fortune_5['profits'].mean()].sort_values('profits', ascending = False)[0:10]
# Out:
#                                   company  rank  revenues  profits  \
# 8                                   Apple     9    215639  45687.0
# 21  Industrial & Commercial Bank of China    22    147675  41883.9
# 27                China Construction Bank    28    135093  34840.9
# 37             Agricultural Bank of China    38    117275  27687.8
# 41                          Bank of China    42    113708  24773.4
# 47                      J.P. Morgan Chase    48    105486  24733.0
# 7                      Berkshire Hathaway     8    223604  24074.0
# 60                            Wells Fargo    61     94176  21938.0
# 64                               Alphabet    65     90272  19478.0
# 14                    Samsung Electronics    15    173957  19316.5
#
#                   ceo
# 8     Timothy D. Cook
# 21             Gu Shu
# 27     Wang Hongzhang
# 37          Zhao Huan
# 41        Chen Siqing
# 47        James Dimon
# 7   Warren E. Buffett
# 60   Timothy J. Sloan
# ...

# %%
fortune_5[['rank','company','ceo','revenues','profits']][fortune_5['profits']>= fortune_5['profits'].mean()].sort_values('profits', ascending = False).head(10)
# Out:
#     rank                                company                ceo  revenues  \
# 8      9                                  Apple    Timothy D. Cook    215639
# 21    22  Industrial & Commercial Bank of China             Gu Shu    147675
# 27    28                China Construction Bank     Wang Hongzhang    135093
# 37    38             Agricultural Bank of China          Zhao Huan    117275
# 41    42                          Bank of China        Chen Siqing    113708
# 47    48                      J.P. Morgan Chase        James Dimon    105486
# 7      8                     Berkshire Hathaway  Warren E. Buffett    223604
# 60    61                            Wells Fargo   Timothy J. Sloan     94176
# 64    65                               Alphabet         Larry Page     90272
# 14    15                    Samsung Electronics       Oh-Hyun Kwon    173957
#
#     profits
# 8   45687.0
# 21  41883.9
# 27  34840.9
# 37  27687.8
# 41  24773.4
# 47  24733.0
# 7   24074.0
# 60  21938.0
# ...

# %%
#.loc....Location of the columns....names...row position
#.iloc

# %%
fortune_5.loc[1:5,'company'] #using .loc we can find specific range of rows from table
# Out:
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# 5                  Volkswagen
# Name: company, dtype: object

# %%
fortune_5.loc[2:10,'company'] #fetch data from rows 2 to 10

# %%
fortune_5.loc[2:10,'company'].head(6) 
# fortune_5.loc[1:10,'company'] -> fetch data from rows 2 to 10 
# head(6)-> fetching first 6 rows from above condition
# Out:
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# 5                  Volkswagen
# 6           Royal Dutch Shell
# Name: company, dtype: object

# %%
avv=fortune_5.loc[2:10,['company','rank','profits']]

# %%
avv
# Out:
#                      company  rank  profits
# 2              Sinopec Group     3   1257.9
# 3   China National Petroleum     4   1867.5
# 4               Toyota Motor     5  16899.3
# 5                 Volkswagen     6   5937.3
# 6          Royal Dutch Shell     7   4575.0
# 7         Berkshire Hathaway     8  24074.0
# 8                      Apple     9  45687.0
# 9                Exxon Mobil    10   7840.0
# 10                  McKesson    11   5070.0

# %%
# .iloc ...........column index values
fortune_5.info()
fortune_5.iloc[123:130,0] # 0 -> for column index number i.e of company
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
abc=fortune_5.iloc[123:130,[0,7,2,4]]     #[0,7,2,4]->we can find more than one column using column index

# %%
abc.sort_values('profits')
# Out:
#                company                  ceo  revenues  profits
# 123  Dell Technologies      Michael S. Dell     64806  -1672.0
# 128        Tewoo Group           Wang Yuzhu     63324    141.7
# 127            MetLife  Steven A. Kandarian     63476    800.0
# 126      JXTG Holdings         Yukio Uchida     63629   1477.3
# 129              Aetna    Mark T. Bertolini     63155   2271.0
# 124    China FAW Group              Xu Ping     64784   2411.3
# 125               BASF         Kurt W. Bock     63641   4485.3

# %%
#load the dataset wh2015 using pandas and load file "World_Happiness_2015"
import pandas as pd

# %%
hap2015=pd.read_csv("World_Happiness_2015.csv")

# %%
hap2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
hap2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#find out all unique regions
hap2015['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
len(hap2015['Region'].unique()) #number of regions
# Out:
# 10

# %%
#find out 3 columns country, region and happiness score such that they are in eastern asia region
hap2015[['Country','Region','Happiness Score']][hap2015['Region']=='Eastern Asia']
# Out:
#         Country        Region  Happiness Score
# 37       Taiwan  Eastern Asia            6.298
# 45        Japan  Eastern Asia            5.987
# 46  South Korea  Eastern Asia            5.984
# 71    Hong Kong  Eastern Asia            5.474
# 83        China  Eastern Asia            5.140
# 99     Mongolia  Eastern Asia            4.874

# %%
#use hap2015 ,create new column and name it as sum_happy and add all the column after after happiness score


sum_happy = (hap2015['Economy (GDP per Capita)'] + hap2015['Family'] +
hap2015['Health (Life Expectancy)'] + hap2015['Freedom'] + hap2015['Trust (Government Corruption)'] +
hap2015['Generosity'] + hap2015['Dystopia Residual'])

# %%
#add new column adding 4 5 columns
hap2015['sum_happy']=(hap2015['Economy (GDP per Capita)'] + hap2015['Family'] +
hap2015['Health (Life Expectancy)'] + hap2015['Freedom'] + hap2015['Trust (Government Corruption)'] +
hap2015['Generosity'] + hap2015['Dystopia Residual'])

# %%
hap2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
hap2015['Happiness Score']
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
#adding one column as year in dataset

hap2015['year']=2015

# %%
hap2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
hap2015['Happiness Score'].mean()
# Out:
# 5.3757341772151905

# %%
#create "status of the country" column 
#assign a tag poor to a country if happiness score is less than the average happiness score
#otherwise assign as rich

# %%
hap2015['Status']=False

# %%
for i in hap2015['Happiness Score']:
    if i<hap2015['Happiness Score'].mean():
        print('Poor Country')
    else:
        print('Rich Country')
# Out:
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# Rich Country
# ...
